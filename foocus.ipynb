# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram

# %%
# !wget -O /kaggle/working/Fooocus/models/loras/Monochrome_Graphic_Etching.safetensors https://civitai.com/api/download/models/1208029
